# %%
from scipy.stats import norm
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder

from class_imbalance_experiment.util import run_experiment, multiclass_imbalance_ratio

# Seed for reproducibility
np.random.seed(42)

# Number of samples
n_samples = 10000

# Class distribution (most in 1)
class_distribution = [0.8, 0.07, 0.055, 0.045, 0.03]
classes = np.arange(1, 6)

le = LabelEncoder()
le.fit(classes)


# Latent variable
z = np.random.normal(0, 1.0, n_samples)

# Find thresholds according to distribution
cum_probs = np.cumsum(class_distribution)
thresholds = np.concatenate(([-np.inf],norm.ppf(cum_probs)))
print(thresholds)

y = np.searchsorted(thresholds, z, side="right")

# Generate ordinal target
#y = np.random.choice(classes, size=n_samples, p=class_distribution)



print("Imbalance Ratio (IR) ", multiclass_imbalance_ratio(y))

# Create features
X1 = z + np.random.normal(0, 1.0, n_samples)
X2 = np.sin(z) + np.random.normal(0, 1.0, n_samples)
X3 = 0.8 * z + np.random.normal(0, 0.2, n_samples)
X4 = 0.5 * z + np.random.normal(0, 0.3, n_samples)

# # Create overlapping features
# # These have weak correlation to the class to keep accuracy moderate (<90%)
# X1 = y + np.random.normal(0, 1.0, n_samples)  # noisy ordinal relation
# X2 = np.sin(y) + np.random.normal(0, 1.0, n_samples)  # nonlinear but correlated
# X3 = np.random.normal(0, 1.0, n_samples)  # mostly noise
# X4 = 0.5 * y + np.random.normal(0, 1.0, n_samples)

# Combine into a DataFrame
data = pd.DataFrame({
    'feature_1': X1,
    'feature_2': X2,
    'feature_3': X3,
    'feature_4': X4,
    'class': y
})

# Assuming `data` DataFrame exists
X = data.drop(columns='class')
y = data['class']
# Out:
# [      -inf 0.84162123 1.12639113 1.43953147 1.88079361        nan]
# [      -inf 0.84162123 1.12639113 1.43953147 1.88079361        nan]
# Imbalance Ratio (IR)  26.249180327868853

# %%
# Overall class distribution
print("\nClass distribution in full dataset:")
print(data['class'].value_counts(normalize=True).sort_index().values)
# Out:
# Class distribution in full dataset:
# [0.8006 0.0683 0.055  0.0456 0.0305]

# %%
from class_imbalance_experiment.util import plot_data_dist

plot_data_dist(data['class'].value_counts(normalize=False).sort_index().values , "right_tail")
# Out:
# C:\Users\Q454199\projects\ordinal-aleatoric-epistemic-uncertainty\class_imbalance_experiment\util.py:36: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.barplot(x=[1,2,3,4,5],y=p,legend=False,palette=colors)

# %%
run_experiment(X, y, le, "right_tail")
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000174 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 9000, number of used features: 4
# [LightGBM] [Info] Start training from score -0.222449
# [LightGBM] [Info] Start training from score -2.683358
# [LightGBM] [Info] Start training from score -2.900422
# [LightGBM] [Info] Start training from score -3.088823
# [LightGBM] [Info] Start training from score -3.488209
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000200 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 9000, number of used features: 4
# [LightGBM] [Info] Start training from score -0.222449
# [LightGBM] [Info] Start training from score -2.683358
# [LightGBM] [Info] Start training from score -2.900422
# [LightGBM] [Info] Start training from score -3.088823
# [LightGBM] [Info] Start training from score -3.488209
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000158 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 9000, number of used features: 4
# [LightGBM] [Info] Start training from score -0.222449
# [LightGBM] [Info] Start training from score -2.683358
# [LightGBM] [Info] Start training from score -2.900422
# [LightGBM] [Info] Start training from score -3.088823
# [LightGBM] [Info] Start training from score -3.488209
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000198 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 9000, number of used features: 4
# [LightGBM] [Info] Start training from score -0.222449
# [LightGBM] [Info] Start training from score -2.683358
# [LightGBM] [Info] Start training from score -2.900422
# [LightGBM] [Info] Start training from score -3.088823
# [LightGBM] [Info] Start training from score -3.488209
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000234 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 9000, number of used features: 4
# [LightGBM] [Info] Start training from score -0.222449
# [LightGBM] [Info] Start training from score -2.683358
# [LightGBM] [Info] Start training from score -2.900422
# [LightGBM] [Info] Start training from score -3.088823
# [LightGBM] [Info] Start training from score -3.488209
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000198 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 9000, number of used features: 4
# [LightGBM] [Info] Start training from score -0.222449
# [LightGBM] [Info] Start training from score -2.683358
# [LightGBM] [Info] Start training from score -2.900422
# [LightGBM] [Info] Start training from score -3.088823
# [LightGBM] [Info] Start training from score -3.488209
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000196 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 9000, number of used features: 4
# [LightGBM] [Info] Start training from score -0.222449
# [LightGBM] [Info] Start training from score -2.683358
# [LightGBM] [Info] Start training from score -2.900422
# [LightGBM] [Info] Start training from score -3.088823
# [LightGBM] [Info] Start training from score -3.488209
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000269 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 9000, number of used features: 4
# [LightGBM] [Info] Start training from score -0.222449
# [LightGBM] [Info] Start training from score -2.683358
# [LightGBM] [Info] Start training from score -2.900422
# [LightGBM] [Info] Start training from score -3.088823
# [LightGBM] [Info] Start training from score -3.488209
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000233 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 9000, number of used features: 4
# [LightGBM] [Info] Start training from score -0.222449
# [LightGBM] [Info] Start training from score -2.683358
# [LightGBM] [Info] Start training from score -2.900422
# [LightGBM] [Info] Start training from score -3.088823
# [LightGBM] [Info] Start training from score -3.488209
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000189 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 9000, number of used features: 4
# [LightGBM] [Info] Start training from score -0.222449
# [LightGBM] [Info] Start training from score -2.683358
# [LightGBM] [Info] Start training from score -2.900422
# [LightGBM] [Info] Start training from score -3.088823
# [LightGBM] [Info] Start training from score -3.488209
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Unimodal predictions: 948 / 1000 (0.948)
#
# Fold 1 Accuracy: 0.89
# Confusion Matrix (Fold 1):
# [[783  17   1   0   0]
#  [ 37  23   6   2   0]
#  [  2  14  30   8   1]
#  [  0   2  13  26   5]
#  [  0   0   0   2  28]]
# Metric: ACC, Measure: Entropy (TU)
# Random: 0.5000126259437894
# ORC: 0.7688442211055276
# Measure: 0.5430959143543805
# PRR: 0.1602612534611893
# Metric: ACC, Measure: Entropy (EU)
# Random: 0.5000126259437894
# ORC: 0.7688442211055276
# Measure: 0.5278020537469958
# PRR: 0.10337113755727785
# Metric: ACC, Measure: Entropy (AU)
# Random: 0.5000126259437894
# ORC: 0.7688442211055276
# Measure: 0.5424404631854927
# PRR: 0.1578231056367361
# Metric: ACC, Measure: Binary Variance (TU)
# Random: 0.5000126259437894
# ORC: 0.7688442211055276
# Measure: 0.5488857330128905
# PRR: 0.1817982259105272
# Metric: ACC, Measure: Binary Variance (EU)
# Random: 0.5000126259437894
# ORC: 0.7688442211055276
# Measure: 0.5381254096569806
# PRR: 0.14177196579241855
# Metric: ACC, Measure: Binary Variance (AU)
# Random: 0.5000126259437894
# ORC: 0.7688442211055276
# Measure: 0.5498142888354818
# PRR: 0.18525226866183653
# Metric: ACC, Measure: Binary Entropy (TU)
# Random: 0.5000126259437894
# ORC: 0.7688442211055276
# Measure: 0.5453353725147476
# PRR: 0.16859159186140504
# Metric: ACC, Measure: Binary Entropy (EU)
# Random: 0.5000126259437894
# ORC: 0.7688442211055276
# Measure: 0.52649115140922
# PRR: 0.09849484190837103
# Metric: ACC, Measure: Binary Entropy (AU)
# Random: 0.5000126259437894
# ORC: 0.7688442211055276
# Measure: 0.5457177190299323
# PRR: 0.17001384475900297
# Metric: ACC, Measure: Variance (TU)
# Random: 0.5000126259437894
# ORC: 0.7688442211055276
# Measure: 0.5482302818440026
# PRR: 0.179360078086074
# Metric: ACC, Measure: Variance (EU)
# Random: 0.5000126259437894
# ORC: 0.7688442211055276
# Measure: 0.5361044352195762
# PRR: 0.13425434333368721
# Metric: ACC, Measure: Variance (AU)
# Random: 0.5000126259437894
# ORC: 0.7688442211055276
# Measure: 0.5479025562595587
# PRR: 0.17814100417384782
# Metric: ACC, Measure: Binary Entropy One vs. Rest (TU)
# Random: 0.5000126259437894
# ORC: 0.7688442211055276
# Measure: 0.5442975748306751
# PRR: 0.16473119113935394
# Metric: ACC, Measure: Binary Entropy One vs. Rest (EU)
# Random: 0.5000126259437894
# ORC: 0.7688442211055276
# Measure: 0.5235416211492243
# PRR: 0.08752317669833078
# Metric: ACC, Measure: Binary Entropy One vs. Rest (AU)
# Random: 0.5000126259437894
# ORC: 0.7688442211055276
# Measure: 0.5447345422766003
# PRR: 0.16635662302232274
# Metric: ACC, Measure: Binary Variance One vs. Rest (TU)
# Random: 0.5000126259437894
# ORC: 0.7688442211055276
# Measure: 0.5453899934454883
# PRR: 0.16879477084677635
# Metric: ACC, Measure: Binary Variance One vs. Rest (EU)
# Random: 0.5000126259437894
# ORC: 0.7688442211055276
# Measure: 0.5361044352195761
# PRR: 0.1342543433336868
# Metric: ACC, Measure: Binary Variance One vs. Rest (AU)
# Random: 0.5000126259437894
# ORC: 0.7688442211055276
# Measure: 0.5464277911295609
# PRR: 0.17265517156882748
# Metric: MAE, Measure: Entropy (TU)
# Random: 0.5000126259437894
# ORC: 0.7970286213677081
# Measure: 0.5238147258029276
# PRR: 0.08013743443401598
# Metric: MAE, Measure: Entropy (EU)
# Random: 0.5000126259437894
# ORC: 0.7970286213677081
# Measure: 0.5311339305221762
# PRR: 0.10477989420727539
# Metric: MAE, Measure: Entropy (AU)
# Random: 0.5000126259437894
# ORC: 0.7970286213677081
# Measure: 0.5217937513655233
# PRR: 0.0733331731533402
# Metric: MAE, Measure: Binary Variance (TU)
# Random: 0.5000126259437894
# ORC: 0.7970286213677081
# Measure: 0.5278566746777364
# PRR: 0.0937459569953679
# Metric: MAE, Measure: Binary Variance (EU)
# Random: 0.5000126259437894
# ORC: 0.7970286213677081
# Measure: 0.5335372514747652
# PRR: 0.11287144816267376
# Metric: MAE, Measure: Binary Variance (AU)
# Random: 0.5000126259437894
# ORC: 0.7970286213677081
# Measure: 0.5280751584006991
# PRR: 0.094481552809495
# Metric: MAE, Measure: Binary Entropy (TU)
# Random: 0.5000126259437894
# ORC: 0.7970286213677081
# Measure: 0.5281844002621805
# PRR: 0.09484935071655892
# Metric: MAE, Measure: Binary Entropy (EU)
# Random: 0.5000126259437894
# ORC: 0.7970286213677081
# Measure: 0.5304784793532882
# PRR: 0.10257310676489374
# Metric: MAE, Measure: Binary Entropy (AU)
# Random: 0.5000126259437894
# ORC: 0.7970286213677081
# Measure: 0.5275289490932926
# PRR: 0.09264256327417765
# Metric: MAE, Measure: Variance (TU)
# Random: 0.5000126259437894
# ORC: 0.7970286213677081
# Measure: 0.5311885514529167
# PRR: 0.1049637931608066
# Metric: MAE, Measure: Variance (EU)
# Random: 0.5000126259437894
# ORC: 0.7970286213677081
# Measure: 0.5253987327944069
# PRR: 0.08547050408643796
# Metric: MAE, Measure: Variance (AU)
# Random: 0.5000126259437894
# ORC: 0.7970286213677081
# Measure: 0.5305877212147695
# PRR: 0.10294090467195728
# Metric: MAE, Measure: Binary Entropy One vs. Rest (TU)
# Random: 0.5000126259437894
# ORC: 0.7970286213677081
# Measure: 0.521848372296264
# PRR: 0.07351707210687217
# Metric: MAE, Measure: Binary Entropy One vs. Rest (EU)
# Random: 0.5000126259437894
# ORC: 0.7970286213677081
# Measure: 0.5312977933143981
# PRR: 0.10533159106787052
# Metric: MAE, Measure: Binary Entropy One vs. Rest (AU)
# Random: 0.5000126259437894
# ORC: 0.7970286213677081
# Measure: 0.5214114048503387
# PRR: 0.07204588047861761
# Metric: MAE, Measure: Binary Variance One vs. Rest (TU)
# Random: 0.5000126259437894
# ORC: 0.7970286213677081
# Measure: 0.521029058335154
# PRR: 0.07075858780389502
# Metric: MAE, Measure: Binary Variance One vs. Rest (EU)
# Random: 0.5000126259437894
# ORC: 0.7970286213677081
# Measure: 0.5345204282280971
# PRR: 0.11618162932624604
# Metric: MAE, Measure: Binary Variance One vs. Rest (AU)
# Random: 0.5000126259437894
# ORC: 0.7970286213677081
# Measure: 0.521356783919598
# PRR: 0.07186198152508602
# Metric: MSE, Measure: Entropy (TU)
# Random: 0.5000126259437894
# ORC: 0.8323901058691516
# Measure: 0.5144411377274724
# PRR: 0.04341001618678561
# Metric: MSE, Measure: Entropy (EU)
# Random: 0.5000126259437894
# ORC: 0.8323901058691516
# Measure: 0.5365419329657999
# PRR: 0.10990307475167521
# Metric: MSE, Measure: Entropy (AU)
# Random: 0.5000126259437894
# ORC: 0.8323901058691516
# Measure: 0.5115138800800118
# PRR: 0.03460298856229692
# Metric: MSE, Measure: Binary Variance (TU)
# Random: 0.5000126259437894
# ORC: 0.8323901058691516
# Measure: 0.5165390057081525
# PRR: 0.04972171931766925
# Metric: MSE, Measure: Binary Variance (EU)
# Random: 0.5000126259437894
# ORC: 0.8323901058691516
# Measure: 0.5339561887105431
# PRR: 0.10212353368337701
# Metric: MSE, Measure: Binary Variance (AU)
# Random: 0.5000126259437894
# ORC: 0.8323901058691516
# Measure: 0.5167341562179831
# PRR: 0.05030885449263501
# Metric: MSE, Measure: Binary Entropy (TU)
# Random: 0.5000126259437894
# ORC: 0.8323901058691516
# Measure: 0.5185392984339172
# PRR: 0.055739854861069846
# Metric: MSE, Measure: Binary Entropy (EU)
# Random: 0.5000126259437894
# ORC: 0.8323901058691516
# Measure: 0.5338586134556277
# PRR: 0.10182996609589397
# Metric: MSE, Measure: Binary Entropy (AU)
# Random: 0.5000126259437894
# ORC: 0.8323901058691516
# Measure: 0.5175635458847636
# PRR: 0.05280417898624006
# Metric: MSE, Measure: Variance (TU)
# Random: 0.5000126259437894
# ORC: 0.8323901058691516
# Measure: 0.5214177684539201
# PRR: 0.06440009869181686
# Metric: MSE, Measure: Variance (EU)
# Random: 0.5000126259437894
# ORC: 0.8323901058691516
# Measure: 0.5200029272576475
# PRR: 0.06014336867331419
# Metric: MSE, Measure: Variance (AU)
# Random: 0.5000126259437894
# ORC: 0.8323901058691516
# Measure: 0.5204420159047666
# PRR: 0.0614644228169874
# Metric: MSE, Measure: Binary Entropy One vs. Rest (TU)
# Random: 0.5000126259437894
# ORC: 0.8323901058691516
# Measure: 0.5116114553349271
# PRR: 0.03489655614977996
# Metric: MSE, Measure: Binary Entropy One vs. Rest (EU)
# Random: 0.5000126259437894
# ORC: 0.8323901058691516
# Measure: 0.5407376689271601
# PRR: 0.12252648101344249
# Metric: MSE, Measure: Binary Entropy One vs. Rest (AU)
# Random: 0.5000126259437894
# ORC: 0.8323901058691516
# Measure: 0.5113675171976387
# PRR: 0.034162637181072514
# Metric: MSE, Measure: Binary Variance One vs. Rest (TU)
# Random: 0.5000126259437894
# ORC: 0.8323901058691516
# Measure: 0.5132702346684881
# PRR: 0.03988720513699007
# Metric: MSE, Measure: Binary Variance One vs. Rest (EU)
# Random: 0.5000126259437894
# ORC: 0.8323901058691516
# Measure: 0.541957359613602
# PRR: 0.1261960758569794
# Metric: MSE, Measure: Binary Variance One vs. Rest (AU)
# Random: 0.5000126259437894
# ORC: 0.8323901058691516
# Measure: 0.5135629604332341
# PRR: 0.04076790789943887
# Metric: ACC, Measure: Entropy (TU)
# Random: 0.5000005000000001
# ORC: 0.9450000000000001
# Measure: 0.8862
# PRR: 0.8678650200730561
# Metric: ACC, Measure: Entropy (EU)
# Random: 0.5000005000000001
# ORC: 0.9450000000000001
# Measure: 0.8769363636363636
# PRR: 0.8470478363152398
# Metric: ACC, Measure: Entropy (AU)
# Random: 0.5000005000000001
# ORC: 0.9450000000000001
# Measure: 0.8861454545454546
# PRR: 0.867742445880174
# Metric: ACC, Measure: Binary Variance (TU)
# Random: 0.5000005000000001
# ORC: 0.9450000000000001
# Measure: 0.8863818181818182
# PRR: 0.8682736007159966
# Metric: ACC, Measure: Binary Variance (EU)
# Random: 0.5000005000000001
# ORC: 0.9450000000000001
# Measure: 0.8799363636363636
# PRR: 0.8537894169237573
# Metric: ACC, Measure: Binary Variance (AU)
# Random: 0.5000005000000001
# ORC: 0.9450000000000001
# Measure: 0.8867
# PRR: 0.8689886168411425
# Metric: ACC, Measure: Binary Entropy (TU)
# Random: 0.5000005000000001
# ORC: 0.9450000000000001
# Measure: 0.8862181818181818
# PRR: 0.8679058781373501
# Metric: ACC, Measure: Binary Entropy (EU)
# Random: 0.5000005000000001
# ORC: 0.9450000000000001
# Measure: 0.8761181818181818
# PRR: 0.8452092234220078
# Metric: ACC, Measure: Binary Entropy (AU)
# Random: 0.5000005000000001
# ORC: 0.9450000000000001
# Measure: 0.8864454545454545
# PRR: 0.8684166039410257
# Metric: ACC, Measure: Variance (TU)
# Random: 0.5000005000000001
# ORC: 0.9450000000000001
# Measure: 0.8857272727272727
# PRR: 0.8668027104014109
# Metric: ACC, Measure: Variance (EU)
# Random: 0.5000005000000001
# ORC: 0.9450000000000001
# Measure: 0.8783545454545454
# PRR: 0.8502347653301753
# Metric: ACC, Measure: Variance (AU)
# Random: 0.5000005000000001
# ORC: 0.9450000000000001
# Measure: 0.8857818181818182
# PRR: 0.8669252845942932
# Metric: ACC, Measure: Binary Entropy One vs. Rest (TU)
# Random: 0.5000005000000001
# ORC: 0.9450000000000001
# Measure: 0.8860454545454546
# PRR: 0.8675177265265568
# Metric: ACC, Measure: Binary Entropy One vs. Rest (EU)
# Random: 0.5000005000000001
# ORC: 0.9450000000000001
# Measure: 0.8746181818181819
# PRR: 0.8418384331177491
# Metric: ACC, Measure: Binary Entropy One vs. Rest (AU)
# Random: 0.5000005000000001
# ORC: 0.9450000000000001
# Measure: 0.886290909090909
# PRR: 0.8680693103945262
# Metric: ACC, Measure: Binary Variance One vs. Rest (TU)
# Random: 0.5000005000000001
# ORC: 0.9450000000000001
# Measure: 0.8860636363636363
# PRR: 0.8675585845908506
# Metric: ACC, Measure: Binary Variance One vs. Rest (EU)
# Random: 0.5000005000000001
# ORC: 0.9450000000000001
# Measure: 0.88
# PRR: 0.8539324201487866
# Metric: ACC, Measure: Binary Variance One vs. Rest (AU)
# Random: 0.5000005000000001
# ORC: 0.9450000000000001
# Measure: 0.8862454545454546
# PRR: 0.8679671652337912
# Metric: MAE, Measure: Entropy (TU)
# Random: 0.5000005000000001
# ORC: 0.9505625
# Measure: 0.8827589285714286
# PRR: 0.8495133379455626
# Metric: MAE, Measure: Entropy (EU)
# Random: 0.5000005000000001
# ORC: 0.9505625
# Measure: 0.8789821428571428
# PRR: 0.8411309494745293
# Metric: MAE, Measure: Entropy (AU)
# Random: 0.5000005000000001
# ORC: 0.9505625
# Measure: 0.8822767857142857
# PRR: 0.8484432458003243
# Metric: MAE, Measure: Binary Variance (TU)
# Random: 0.5000005000000001
# ORC: 0.9505625
# Measure: 0.8825446428571428
# PRR: 0.8490377414365677
# Metric: MAE, Measure: Binary Variance (EU)
# Random: 0.5000005000000001
# ORC: 0.9505625
# Measure: 0.8805803571428572
# PRR: 0.8446781067707823
# Metric: MAE, Measure: Binary Variance (AU)
# Random: 0.5000005000000001
# ORC: 0.9505625
# Measure: 0.8825625
# PRR: 0.8490773744789841
# Metric: MAE, Measure: Binary Entropy (TU)
# Random: 0.5000005000000001
# ORC: 0.9505625
# Measure: 0.8830178571428571
# PRR: 0.8500880170605979
# Metric: MAE, Measure: Binary Entropy (EU)
# Random: 0.5000005000000001
# ORC: 0.9505625
# Measure: 0.8784107142857143
# PRR: 0.8398626921172098
# Metric: MAE, Measure: Binary Entropy (AU)
# Random: 0.5000005000000001
# ORC: 0.9505625
# Measure: 0.8829821428571428
# PRR: 0.8500087509757654
# Metric: MAE, Measure: Variance (TU)
# Random: 0.5000005000000001
# ORC: 0.9505625
# Measure: 0.8824732142857143
# PRR: 0.848879209266903
# Metric: MAE, Measure: Variance (EU)
# Random: 0.5000005000000001
# ORC: 0.9505625
# Measure: 0.8774285714285714
# PRR: 0.837682874784317
# Metric: MAE, Measure: Variance (AU)
# Random: 0.5000005000000001
# ORC: 0.9505625
# Measure: 0.8824017857142857
# PRR: 0.848720677097238
# Metric: MAE, Measure: Binary Entropy One vs. Rest (TU)
# Random: 0.5000005000000001
# ORC: 0.9505625
# Measure: 0.8820535714285714
# PRR: 0.8479478327701214
# Metric: MAE, Measure: Binary Entropy One vs. Rest (EU)
# Random: 0.5000005000000001
# ORC: 0.9505625
# Measure: 0.8778482142857142
# PRR: 0.8386142512810983
# Metric: MAE, Measure: Binary Entropy One vs. Rest (AU)
# Random: 0.5000005000000001
# ORC: 0.9505625
# Measure: 0.8819107142857143
# PRR: 0.8476307684307917
# Metric: MAE, Measure: Binary Variance One vs. Rest (TU)
# Random: 0.5000005000000001
# ORC: 0.9505625
# Measure: 0.8817142857142857
# PRR: 0.8471948049642128
# Metric: MAE, Measure: Binary Variance One vs. Rest (EU)
# Random: 0.5000005000000001
# ORC: 0.9505625
# Measure: 0.8813035714285714
# PRR: 0.8462832449886396
# Metric: MAE, Measure: Binary Variance One vs. Rest (AU)
# Random: 0.5000005000000001
# ORC: 0.9505625
# Measure: 0.8814642857142857
# PRR: 0.8466399423703856
# Metric: MSE, Measure: Entropy (TU)
# Random: 0.5000005000000001
# ORC: 0.957
# Measure: 0.8829140625
# PRR: 0.8378861738360766
# Metric: MSE, Measure: Entropy (EU)
# Random: 0.5000005000000001
# ORC: 0.957
# Measure: 0.882765625
# PRR: 0.8375613649467888
# Metric: MSE, Measure: Entropy (AU)
# Random: 0.5000005000000001
# ORC: 0.957
# Measure: 0.8821328125
# PRR: 0.8361766533661416
# Metric: MSE, Measure: Binary Variance (TU)
# Random: 0.5000005000000001
# ORC: 0.957
# Measure: 0.8824296875
# PRR: 0.8368262711447167
# Metric: MSE, Measure: Binary Variance (EU)
# Random: 0.5000005000000001
# ORC: 0.957
# Measure: 0.8836640625
# PRR: 0.8395273134872139
# Metric: MSE, Measure: Binary Variance (AU)
# Random: 0.5000005000000001
# ORC: 0.957
# Measure: 0.88234375
# PRR: 0.836638223893024
# Metric: MSE, Measure: Binary Entropy (TU)
# Random: 0.5000005000000001
# ORC: 0.957
# Measure: 0.883
# PRR: 0.8380742210877693
# Metric: MSE, Measure: Binary Entropy (EU)
# Random: 0.5000005000000001
# ORC: 0.957
# Measure: 0.8817421875
# PRR: 0.8353218931311741
# Metric: MSE, Measure: Binary Entropy (AU)
# Random: 0.5000005000000001
# ORC: 0.957
# Measure: 0.8828515625
# PRR: 0.8377494121984815
# Metric: MSE, Measure: Variance (TU)
# Random: 0.5000005000000001
# ORC: 0.957
# Measure: 0.8825234375
# PRR: 0.8370314136011089
# Metric: MSE, Measure: Variance (EU)
# Random: 0.5000005000000001
# ORC: 0.957
# Measure: 0.879140625
# PRR: 0.8296291899662911
# Metric: MSE, Measure: Variance (AU)
# Random: 0.5000005000000001
# ORC: 0.957
# Measure: 0.882265625
# PRR: 0.8364672718460306
# Metric: MSE, Measure: Binary Entropy One vs. Rest (TU)
# Random: 0.5000005000000001
# ORC: 0.957
# Measure: 0.882171875
# PRR: 0.8362621293896384
# Metric: MSE, Measure: Binary Entropy One vs. Rest (EU)
# Random: 0.5000005000000001
# ORC: 0.957
# Measure: 0.8826796875
# PRR: 0.837373317695096
# Metric: MSE, Measure: Binary Entropy One vs. Rest (AU)
# Random: 0.5000005000000001
# ORC: 0.957
# Measure: 0.881796875
# PRR: 0.8354415595640696
# Metric: MSE, Measure: Binary Variance One vs. Rest (TU)
# Random: 0.5000005000000001
# ORC: 0.957
# Measure: 0.8822656249999999
# PRR: 0.8364672718460304
# Metric: MSE, Measure: Binary Variance One vs. Rest (EU)
# Random: 0.5000005000000001
# ORC: 0.957
# Measure: 0.885828125
# PRR: 0.8442626851889334
# Metric: MSE, Measure: Binary Variance One vs. Rest (AU)
# Random: 0.5000005000000001
# ORC: 0.957
# Measure: 0.8817265625
# PRR: 0.8352877027217755
# Metric: ACC, Measure: Entropy (TU)
# Random: 0.500000779300531
# ORC: 0.9887640449438202
# Measure: 0.9824524899431267
# PRR: 0.987086682972407
# Metric: ACC, Measure: Entropy (EU)
# Random: 0.500000779300531
# ORC: 0.9887640449438202
# Measure: 0.9743376335136635
# PRR: 0.9704838467940727
# Metric: ACC, Measure: Entropy (AU)
# Random: 0.500000779300531
# ORC: 0.9887640449438202
# Measure: 0.9825912054376474
# PRR: 0.9873704921378486
# Metric: ACC, Measure: Binary Variance (TU)
# Random: 0.500000779300531
# ORC: 0.9887640449438202
# Measure: 0.9808572617561382
# PRR: 0.9838228775698283
# Metric: ACC, Measure: Binary Variance (EU)
# Random: 0.500000779300531
# ORC: 0.9887640449438202
# Measure: 0.9745457067554446
# PRR: 0.9709095605422351
# Metric: ACC, Measure: Binary Variance (AU)
# Random: 0.500000779300531
# ORC: 0.9887640449438202
# Measure: 0.9811346927451797
# PRR: 0.9843904959007117
# Metric: ACC, Measure: Binary Entropy (TU)
# Random: 0.500000779300531
# ORC: 0.9887640449438202
# Measure: 0.9814814814814815
# PRR: 0.9851000188143155
# Metric: ACC, Measure: Binary Entropy (EU)
# Random: 0.500000779300531
# ORC: 0.9887640449438202
# Measure: 0.9735746982937995
# PRR: 0.9689228963841439
# Metric: ACC, Measure: Binary Entropy (AU)
# Random: 0.500000779300531
# ORC: 0.9887640449438202
# Measure: 0.9816895547232626
# PRR: 0.9855257325624779
# Metric: ACC, Measure: Variance (TU)
# Random: 0.500000779300531
# ORC: 0.9887640449438202
# Measure: 0.9794701068109308
# PRR: 0.9809847859154123
# Metric: ACC, Measure: Variance (EU)
# Random: 0.500000779300531
# ORC: 0.9887640449438202
# Measure: 0.9725343320848939
# PRR: 0.9667943276433317
# Metric: ACC, Measure: Variance (AU)
# Random: 0.500000779300531
# ORC: 0.9887640449438202
# Measure: 0.9798168955472327
# PRR: 0.9816943088290164
# Metric: ACC, Measure: Binary Entropy One vs. Rest (TU)
# Random: 0.500000779300531
# ORC: 0.9887640449438202
# Measure: 0.9823137744486059
# PRR: 0.9868028738069652
# Metric: ACC, Measure: Binary Entropy One vs. Rest (EU)
# Random: 0.500000779300531
# ORC: 0.9887640449438202
# Measure: 0.9728117630739355
# PRR: 0.9673619459742151
# Metric: ACC, Measure: Binary Entropy One vs. Rest (AU)
# Random: 0.500000779300531
# ORC: 0.9887640449438202
# Measure: 0.9821750589540852
# PRR: 0.9865190646415236
# Metric: ACC, Measure: Binary Variance One vs. Rest (TU)
# Random: 0.500000779300531
# ORC: 0.9887640449438202
# Measure: 0.9813427659869608
# PRR: 0.9848162096488741
# Metric: ACC, Measure: Binary Variance One vs. Rest (EU)
# Random: 0.500000779300531
# ORC: 0.9887640449438202
# Measure: 0.9758635039533916
# PRR: 0.9736057476139304
# Metric: ACC, Measure: Binary Variance One vs. Rest (AU)
# Random: 0.500000779300531
# ORC: 0.9887640449438202
# Measure: 0.9816201969760022
# PRR: 0.9853838279797571
# Metric: MAE, Measure: Entropy (TU)
# Random: 0.500000779300531
# ORC: 0.9887016229712859
# Measure: 0.9825842696629213
# PRR: 0.9874824171318887
# Metric: MAE, Measure: Entropy (EU)
# Random: 0.500000779300531
# ORC: 0.9887016229712859
# Measure: 0.9757802746566792
# PRR: 0.9735597994520507
# Metric: MAE, Measure: Entropy (AU)
# Random: 0.500000779300531
# ORC: 0.9887016229712859
# Measure: 0.982521847690387
# PRR: 0.9873546866944589
# Metric: MAE, Measure: Binary Variance (TU)
# Random: 0.500000779300531
# ORC: 0.9887016229712859
# Measure: 0.9810237203495631
# PRR: 0.9842891561961461
# Metric: MAE, Measure: Binary Variance (EU)
# Random: 0.500000779300531
# ORC: 0.9887016229712859
# Measure: 0.9765917602996255
# PRR: 0.9752202951386368
# Metric: MAE, Measure: Binary Variance (AU)
# Random: 0.500000779300531
# ORC: 0.9887016229712859
# Measure: 0.9812109862671661
# PRR: 0.9846723475084352
# Metric: MAE, Measure: Binary Entropy (TU)
# Random: 0.500000779300531
# ORC: 0.9887016229712859
# Measure: 0.9815230961298377
# PRR: 0.9853109996955837
# Metric: MAE, Measure: Binary Entropy (EU)
# Random: 0.500000779300531
# ORC: 0.9887016229712859
# Measure: 0.9750936329588015
# PRR: 0.9721547646403238
# Metric: MAE, Measure: Binary Entropy (AU)
# Random: 0.500000779300531
# ORC: 0.9887016229712859
# Measure: 0.981585518102372
# PRR: 0.9854387301330134
# Metric: MAE, Measure: Variance (TU)
# Random: 0.500000779300531
# ORC: 0.9887016229712859
# Measure: 0.9795880149812735
# PRR: 0.9813513561352629
# Metric: MAE, Measure: Variance (EU)
# Random: 0.500000779300531
# ORC: 0.9887016229712859
# Measure: 0.9745942571785269
# PRR: 0.9711329211408863
# Metric: MAE, Measure: Variance (AU)
# Random: 0.500000779300531
# ORC: 0.9887016229712859
# Measure: 0.9798377028714107
# PRR: 0.9818622778849815
# Metric: MAE, Measure: Binary Entropy One vs. Rest (TU)
# Random: 0.500000779300531
# ORC: 0.9887016229712859
# Measure: 0.9824594257178527
# PRR: 0.9872269562570293
# Metric: MAE, Measure: Binary Entropy One vs. Rest (EU)
# Random: 0.500000779300531
# ORC: 0.9887016229712859
# Measure: 0.9747191011235955
# PRR: 0.9713883820157456
# Metric: MAE, Measure: Binary Entropy One vs. Rest (AU)
# Random: 0.500000779300531
# ORC: 0.9887016229712859
# Measure: 0.9822097378277154
# PRR: 0.9867160345073105
# Metric: MAE, Measure: Binary Variance One vs. Rest (TU)
# Random: 0.500000779300531
# ORC: 0.9887016229712859
# Measure: 0.9817103620474407
# PRR: 0.9856941910078727
# Metric: MAE, Measure: Binary Variance One vs. Rest (EU)
# Random: 0.500000779300531
# ORC: 0.9887016229712859
# Measure: 0.9777777777777777
# PRR: 0.9776471734498012
# Metric: MAE, Measure: Binary Variance One vs. Rest (AU)
# Random: 0.500000779300531
# ORC: 0.9887016229712859
# Measure: 0.9816479400749064
# PRR: 0.9855664605704432
# Metric: MSE, Measure: Entropy (TU)
# Random: 0.500000779300531
# ORC: 0.9878401997503121
# Measure: 0.9835955056179775
# PRR: 0.9912989931637318
# Metric: MSE, Measure: Entropy (EU)
# Random: 0.500000779300531
# ORC: 0.9878401997503121
# Measure: 0.977752808988764
# PRR: 0.9793223131655747
# Metric: MSE, Measure: Entropy (AU)
# Random: 0.500000779300531
# ORC: 0.9878401997503121
# Measure: 0.9834456928838952
# PRR: 0.9909918988048049
# Metric: MSE, Measure: Binary Variance (TU)
# Random: 0.500000779300531
# ORC: 0.9878401997503121
# Measure: 0.9821972534332085
# PRR: 0.988432779147079
# Metric: MSE, Measure: Binary Variance (EU)
# Random: 0.500000779300531
# ORC: 0.9878401997503121
# Measure: 0.979350811485643
# PRR: 0.982597986327464
# Metric: MSE, Measure: Binary Variance (AU)
# Random: 0.500000779300531
# ORC: 0.9878401997503121
# Measure: 0.9823470661672908
# PRR: 0.988739873506006
# Metric: MSE, Measure: Binary Entropy (TU)
# Random: 0.500000779300531
# ORC: 0.9878401997503121
# Measure: 0.9825468164794008
# PRR: 0.9891493326512423
# Metric: MSE, Measure: Binary Entropy (EU)
# Random: 0.500000779300531
# ORC: 0.9878401997503121
# Measure: 0.9770536828963795
# PRR: 0.9778892061572482
# Metric: MSE, Measure: Binary Entropy (AU)
# Random: 0.500000779300531
# ORC: 0.9878401997503121
# Measure: 0.9825967540574282
# PRR: 0.9892516974375511
# Metric: MSE, Measure: Variance (TU)
# Random: 0.500000779300531
# ORC: 0.9878401997503121
# Measure: 0.9807990012484394
# PRR: 0.985566565130426
# Metric: MSE, Measure: Variance (EU)
# Random: 0.500000779300531
# ORC: 0.9878401997503121
# Measure: 0.9775031210986267
# PRR: 0.9788104892340296
# Metric: MSE, Measure: Variance (AU)
# Random: 0.500000779300531
# ORC: 0.9878401997503121
# Measure: 0.9810486891385768
# PRR: 0.9860783890619711
# Metric: MSE, Measure: Binary Entropy One vs. Rest (TU)
# Random: 0.500000779300531
# ORC: 0.9878401997503121
# Measure: 0.9835455680399501
# PRR: 0.991196628377423
# Metric: MSE, Measure: Binary Entropy One vs. Rest (EU)
# Random: 0.500000779300531
# ORC: 0.9878401997503121
# Measure: 0.9770037453183521
# PRR: 0.9777868413709393
# Metric: MSE, Measure: Binary Entropy One vs. Rest (AU)
# Random: 0.500000779300531
# ORC: 0.9878401997503121
# Measure: 0.9832459425717852
# PRR: 0.9905824396595686
# Metric: MSE, Measure: Binary Variance One vs. Rest (TU)
# Random: 0.500000779300531
# ORC: 0.9878401997503121
# Measure: 0.9830461922596754
# PRR: 0.9901729805143324
# Metric: MSE, Measure: Binary Variance One vs. Rest (EU)
# Random: 0.500000779300531
# ORC: 0.9878401997503121
# Measure: 0.9802996254681648
# PRR: 0.9845429172673357
# Metric: MSE, Measure: Binary Variance One vs. Rest (AU)
# Random: 0.500000779300531
# ORC: 0.9878401997503121
# Measure: 0.9823970037453184
# PRR: 0.9888422382923151
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000180 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 9000, number of used features: 4
# [LightGBM] [Info] Start training from score -0.222449
# [LightGBM] [Info] Start training from score -2.683358
# [LightGBM] [Info] Start training from score -2.900422
# [LightGBM] [Info] Start training from score -3.088823
# [LightGBM] [Info] Start training from score -3.488209
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000172 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 9000, number of used features: 4
# [LightGBM] [Info] Start training from score -0.222449
# [LightGBM] [Info] Start training from score -2.683358
# [LightGBM] [Info] Start training from score -2.900422
# [LightGBM] [Info] Start training from score -3.088823
# [LightGBM] [Info] Start training from score -3.488209
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000193 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 9000, number of used features: 4
# [LightGBM] [Info] Start training from score -0.222449
# [LightGBM] [Info] Start training from score -2.683358
# [LightGBM] [Info] Start training from score -2.900422
# [LightGBM] [Info] Start training from score -3.088823
# [LightGBM] [Info] Start training from score -3.488209
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000189 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 9000, number of used features: 4
# [LightGBM] [Info] Start training from score -0.222449
# [LightGBM] [Info] Start training from score -2.683358
# [LightGBM] [Info] Start training from score -2.900422
# [LightGBM] [Info] Start training from score -3.088823
# [LightGBM] [Info] Start training from score -3.488209
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000214 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 9000, number of used features: 4
# [LightGBM] [Info] Start training from score -0.222449
# [LightGBM] [Info] Start training from score -2.683358
# [LightGBM] [Info] Start training from score -2.900422
# [LightGBM] [Info] Start training from score -3.088823
# [LightGBM] [Info] Start training from score -3.488209
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000157 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 9000, number of used features: 4
# [LightGBM] [Info] Start training from score -0.222449
# [LightGBM] [Info] Start training from score -2.683358
# [LightGBM] [Info] Start training from score -2.900422
# [LightGBM] [Info] Start training from score -3.088823
# [LightGBM] [Info] Start training from score -3.488209
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000217 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 9000, number of used features: 4
# [LightGBM] [Info] Start training from score -0.222449
# [LightGBM] [Info] Start training from score -2.683358
# [LightGBM] [Info] Start training from score -2.900422
# [LightGBM] [Info] Start training from score -3.088823
# [LightGBM] [Info] Start training from score -3.488209
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000157 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 9000, number of used features: 4
# [LightGBM] [Info] Start training from score -0.222449
# [LightGBM] [Info] Start training from score -2.683358
# [LightGBM] [Info] Start training from score -2.900422
# [LightGBM] [Info] Start training from score -3.088823
# [LightGBM] [Info] Start training from score -3.488209
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000161 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 9000, number of used features: 4
# [LightGBM] [Info] Start training from score -0.222449
# [LightGBM] [Info] Start training from score -2.683358
# [LightGBM] [Info] Start training from score -2.900422
# [LightGBM] [Info] Start training from score -3.088823
# [LightGBM] [Info] Start training from score -3.488209
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000183 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1020
# [LightGBM] [Info] Number of data points in the train set: 9000, number of used features: 4
# [LightGBM] [Info] Start training from score -0.222449
# [LightGBM] [Info] Start training from score -2.683358
# [LightGBM] [Info] Start training from score -2.900422
# [LightGBM] [Info] Start training from score -3.088823
# [LightGBM] [Info] Start training from score -3.488209
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Unimodal predictions: 946 / 1000 (0.946)
#
# Fold 2 Accuracy: 0.86
# Confusion Matrix (Fold 2):
# [[770  23   8   0   0]
#  [ 27  25  12   4   0]
#  [  3  24  19   8   1]
#  [  1   4   9  26   6]
#  [  0   0   2   7  21]]
# Metric: ACC, Measure: Entropy (TU)
# Random: 0.5000126259437894
# ORC: 0.728643216080402
# Measure: 0.527963893541783
# PRR: 0.12225515221428598
# Metric: ACC, Measure: Entropy (EU)
# Random: 0.5000126259437894
# ORC: 0.728643216080402
# Measure: 0.5298250511818352
# PRR: 0.13039560987981597
# Metric: ACC, Measure: Entropy (AU)
# Random: 0.5000126259437894
# ORC: 0.728643216080402
# Measure: 0.5278708356597803
# PRR: 0.12184812933100933
# Metric: ACC, Measure: Binary Variance (TU)
# Random: 0.5000126259437894
# ORC: 0.728643216080402
# Measure: 0.5356876977479993
# PRR: 0.15603805152623348
# Metric: ACC, Measure: Binary Variance (EU)
# Random: 0.5000126259437894
# ORC: 0.728643216080402
# Measure: 0.5342453005769588
# PRR: 0.14972919683544791
# Metric: ACC, Measure: Binary Variance (AU)
# Random: 0.5000126259437894
# ORC: 0.728643216080402
# Measure: 0.534105713753955
# PRR: 0.14911866251053343
# Metric: ACC, Measure: Binary Entropy (TU)
# Random: 0.5000126259437894
# ORC: 0.728643216080402
# Measure: 0.5337800111669458
# PRR: 0.14769408241906565
# Metric: ACC, Measure: Binary Entropy (EU)
# Random: 0.5000126259437894
# ORC: 0.728643216080402
# Measure: 0.5280104224827844
# PRR: 0.12245866365592478
# Metric: ACC, Measure: Binary Entropy (AU)
# Random: 0.5000126259437894
# ORC: 0.728643216080402
# Measure: 0.5332216638749302
# PRR: 0.14525194511940676
# Metric: ACC, Measure: Variance (TU)
# Random: 0.5000126259437894
# ORC: 0.728643216080402
# Measure: 0.5378745579750606
# PRR: 0.16560308928323078
# Metric: ACC, Measure: Variance (EU)
# Random: 0.5000126259437894
# ORC: 0.728643216080402
# Measure: 0.5387586078540854
# PRR: 0.16946980667435746
# Metric: ACC, Measure: Variance (AU)
# Random: 0.5000126259437894
# ORC: 0.728643216080402
# Measure: 0.5372231528010423
# PRR: 0.16275392910029524
# Metric: ACC, Measure: Binary Entropy One vs. Rest (TU)
# Random: 0.5000126259437894
# ORC: 0.728643216080402
# Measure: 0.5277777777777778
# PRR: 0.12144110644773318
# Metric: ACC, Measure: Binary Entropy One vs. Rest (EU)
# Random: 0.5000126259437894
# ORC: 0.728643216080402
# Measure: 0.5275451330727713
# PRR: 0.12042354923954204
# Metric: ACC, Measure: Binary Entropy One vs. Rest (AU)
# Random: 0.5000126259437894
# ORC: 0.728643216080402
# Measure: 0.5271729015447608
# PRR: 0.11879545770643594
# Metric: ACC, Measure: Binary Variance One vs. Rest (TU)
# Random: 0.5000126259437894
# ORC: 0.728643216080402
# Measure: 0.5270798436627583
# PRR: 0.11838843482315979
# Metric: ACC, Measure: Binary Variance One vs. Rest (EU)
# Random: 0.5000126259437894
# ORC: 0.728643216080402
# Measure: 0.5271263726037596
# PRR: 0.1185919462647981
# Metric: ACC, Measure: Binary Variance One vs. Rest (AU)
# Random: 0.5000126259437894
# ORC: 0.728643216080402
# Measure: 0.5273590173087661
# PRR: 0.11960950347298924
# Metric: MAE, Measure: Entropy (TU)
# Random: 0.5000126259437894
# ORC: 0.7625939615432534
# Measure: 0.5272021263341501
# PRR: 0.10354696508907625
# Metric: MAE, Measure: Entropy (EU)
# Random: 0.5000126259437894
# ORC: 0.7625939615432534
# Measure: 0.5270360064786743
# PRR: 0.10291432356832034
# Metric: MAE, Measure: Entropy (AU)
# Random: 0.5000126259437894
# ORC: 0.7625939615432534
# Measure: 0.5272851862618879
# PRR: 0.103863285849454
# Metric: MAE, Measure: Binary Variance (TU)
# Random: 0.5000126259437894
# ORC: 0.7625939615432534
# Measure: 0.5365463682046596
# PRR: 0.13913305063158807
# Metric: MAE, Measure: Binary Variance (EU)
# Random: 0.5000126259437894
# ORC: 0.7625939615432534
# Measure: 0.5303584035881889
# PRR: 0.1155671539834358
# Metric: MAE, Measure: Binary Variance (AU)
# Random: 0.5000126259437894
# ORC: 0.7625939615432534
# Measure: 0.5351758793969849
# PRR: 0.13391375808535289
# Metric: MAE, Measure: Binary Entropy (TU)
# Random: 0.5000126259437894
# ORC: 0.7625939615432534
# Measure: 0.5343868100834752
# PRR: 0.1309087108617632
# Metric: MAE, Measure: Binary Entropy (EU)
# Random: 0.5000126259437894
# ORC: 0.7625939615432534
# Measure: 0.5274513061173636
# PRR: 0.1044959273702095
# Metric: MAE, Measure: Binary Entropy (AU)
# Random: 0.5000126259437894
# ORC: 0.7625939615432534
# Measure: 0.5336392707338344
# PRR: 0.1280618240183622
# Metric: MAE, Measure: Variance (TU)
# Random: 0.5000126259437894
# ORC: 0.7625939615432534
# Measure: 0.5384567465426305
# PRR: 0.14640842812027968
# Metric: MAE, Measure: Variance (EU)
# Random: 0.5000126259437894
# ORC: 0.7625939615432534
# Measure: 0.5360064786743635
# PRR: 0.13707696568913164
# Metric: MAE, Measure: Variance (AU)
# Random: 0.5000126259437894
# ORC: 0.7625939615432534
# Measure: 0.5377092071929896
# PRR: 0.14356154127687826
# Metric: MAE, Measure: Binary Entropy One vs. Rest (TU)
# Random: 0.5000126259437894
# ORC: 0.7625939615432534
# Measure: 0.5275343660451015
# PRR: 0.10481224813058768
# Metric: MAE, Measure: Binary Entropy One vs. Rest (EU)
# Random: 0.5000126259437894
# ORC: 0.7625939615432534
# Measure: 0.5252917479961792
# PRR: 0.09627158760038464
# Metric: MAE, Measure: Binary Entropy One vs. Rest (AU)
# Random: 0.5000126259437894
# ORC: 0.7625939615432534
# Measure: 0.5267037667677229
# PRR: 0.10164904052680891
# Metric: MAE, Measure: Binary Variance One vs. Rest (TU)
# Random: 0.5000126259437894
# ORC: 0.7625939615432534
# Measure: 0.5265376469122471
# PRR: 0.101016399006053
# Metric: MAE, Measure: Binary Variance One vs. Rest (EU)
# Random: 0.5000126259437894
# ORC: 0.7625939615432534
# Measure: 0.5229660700195191
# PRR: 0.08741460630980427
# Metric: MAE, Measure: Binary Variance One vs. Rest (AU)
# Random: 0.5000126259437894
# ORC: 0.7625939615432534
# Measure: 0.5266622368038539
# PRR: 0.10149088014661983
# Metric: MSE, Measure: Entropy (TU)
# Random: 0.5000126259437894
# ORC: 0.8072716523795448
# Measure: 0.5157035175879396
# PRR: 0.05106730899386961
# Metric: MSE, Measure: Entropy (EU)
# Random: 0.5000126259437894
# ORC: 0.8072716523795448
# Measure: 0.5132648536801655
# PRR: 0.04313047492893437
# Metric: MSE, Measure: Entropy (AU)
# Random: 0.5000126259437894
# ORC: 0.8072716523795448
# Measure: 0.515407921962755
# PRR: 0.05010526850115045
# Metric: MSE, Measure: Binary Variance (TU)
# Random: 0.5000126259437894
# ORC: 0.8072716523795448
# Measure: 0.5175509902453443
# PRR: 0.05708006207336617
# Metric: MSE, Measure: Binary Variance (EU)
# Random: 0.5000126259437894
# ORC: 0.8072716523795448
# Measure: 0.5110478864912799
# PRR: 0.0359151712335385
# Metric: MSE, Measure: Binary Variance (AU)
# Random: 0.5000126259437894
# ORC: 0.8072716523795448
# Measure: 0.5170706473544191
# PRR: 0.05551674627269699
# Metric: MSE, Measure: Binary Entropy (TU)
# Random: 0.5000126259437894
# ORC: 0.8072716523795448
# Measure: 0.5168120011823825
# PRR: 0.054674960841567546
# Metric: MSE, Measure: Binary Entropy (EU)
# Random: 0.5000126259437894
# ORC: 0.8072716523795448
# Measure: 0.5136712976647946
# PRR: 0.044453280606423756
# Metric: MSE, Measure: Binary Entropy (AU)
# Random: 0.5000126259437894
# ORC: 0.8072716523795448
# Measure: 0.5164055571977535
# PRR: 0.05335215516407852
# Metric: MSE, Measure: Variance (TU)
# Random: 0.5000126259437894
# ORC: 0.8072716523795448
# Measure: 0.5186964232929352
# PRR: 0.060807968982653816
# Metric: MSE, Measure: Variance (EU)
# Random: 0.5000126259437894
# ORC: 0.8072716523795448
# Measure: 0.5165164055571978
# PRR: 0.053712920348848385
# Metric: MSE, Measure: Variance (AU)
# Random: 0.5000126259437894
# ORC: 0.8072716523795448
# Measure: 0.5184377771208986
# PRR: 0.059966183551524374
# Metric: MSE, Measure: Binary Entropy One vs. Rest (TU)
# Random: 0.5000126259437894
# ORC: 0.8072716523795448
# Measure: 0.5157035175879396
# PRR: 0.05106730899386961
# Metric: MSE, Measure: Binary Entropy One vs. Rest (EU)
# Random: 0.5000126259437894
# ORC: 0.8072716523795448
# Measure: 0.511084835944428
# PRR: 0.03603542629512858
# Metric: MSE, Measure: Binary Entropy One vs. Rest (AU)
# Random: 0.5000126259437894
# ORC: 0.8072716523795448
# Measure: 0.5148906296186816
# PRR: 0.0484216976388912
# Metric: MSE, Measure: Binary Variance One vs. Rest (TU)
# Random: 0.5000126259437894
# ORC: 0.8072716523795448
# Measure: 0.5145580845403488
# PRR: 0.04733940208458196
# Metric: MSE, Measure: Binary Variance One vs. Rest (EU)
# Random: 0.5000126259437894
# ORC: 0.8072716523795448
# Measure: 0.5056163168785102
# PRR: 0.018237677179819053
# Metric: MSE, Measure: Binary Variance One vs. Rest (AU)
# Random: 0.5000126259437894
# ORC: 0.8072716523795448
# Measure: 0.5153709725096068
# PRR: 0.049985013439560376
# Metric: ACC, Measure: Entropy (TU)
# Random: 0.5000005000000001
# ORC: 0.9305
# Measure: 0.8781474820143885
# PRR: 0.8783912223228796
# Metric: ACC, Measure: Entropy (EU)
# Random: 0.5000005000000001
# ORC: 0.9305
# Measure: 0.871341726618705
# PRR: 0.8625822483387438
# Metric: ACC, Measure: Entropy (AU)
# Random: 0.5000005000000001
# ORC: 0.9305
# Measure: 0.8781402877697841
# PRR: 0.87837451093389
# Metric: ACC, Measure: Binary Variance (TU)
# Random: 0.5000005000000001
# ORC: 0.9305
# Measure: 0.8779172661870503
# PRR: 0.8778564578752132
# Metric: ACC, Measure: Binary Variance (EU)
# Random: 0.5000005000000001
# ORC: 0.9305
# Measure: 0.8728741007194245
# PRR: 0.8661417741935229
# Metric: ACC, Measure: Binary Variance (AU)
# Random: 0.5000005000000001
# ORC: 0.9305
# Measure: 0.877931654676259
# PRR: 0.8778898806531924
# Metric: ACC, Measure: Binary Entropy (TU)
# Random: 0.5000005000000001
# ORC: 0.9305
# Measure: 0.8786223021582734
# PRR: 0.8794941739961915
# Metric: ACC, Measure: Binary Entropy (EU)
# Random: 0.5000005000000001
# ORC: 0.9305
# Measure: 0.8709604316546763
# PRR: 0.8616965447222965
# Metric: ACC, Measure: Binary Entropy (AU)
# Random: 0.5000005000000001
# ORC: 0.9305
# Measure: 0.8786798561151079
# PRR: 0.8796278651081079
# Metric: ACC, Measure: Variance (TU)
# Random: 0.5000005000000001
# ORC: 0.9305
# Measure: 0.8776798561151079
# PRR: 0.8773049820385573
# Metric: ACC, Measure: Variance (EU)
# Random: 0.5000005000000001
# ORC: 0.9305
# Measure: 0.8730827338129497
# PRR: 0.8666264044742205
# Metric: ACC, Measure: Variance (AU)
# Random: 0.5000005000000001
# ORC: 0.9305
# Measure: 0.8777230215827339
# PRR: 0.8774052503724948
# Metric: ACC, Measure: Binary Entropy One vs. Rest (TU)
# Random: 0.5000005000000001
# ORC: 0.9305
# Measure: 0.8774496402877698
# PRR: 0.8767702175908911
# Metric: ACC, Measure: Binary Entropy One vs. Rest (EU)
# Random: 0.5000005000000001
# ORC: 0.9305
# Measure: 0.8693201438848921
# PRR: 0.8578863480326738
# Metric: ACC, Measure: Binary Entropy One vs. Rest (AU)
# Random: 0.5000005000000001
# ORC: 0.9305
# Measure: 0.8774496402877698
# PRR: 0.8767702175908911
# Metric: ACC, Measure: Binary Variance One vs. Rest (TU)
# Random: 0.5000005000000001
# ORC: 0.9305
# Measure: 0.8763992805755396
# PRR: 0.8743303547984135
# Metric: ACC, Measure: Binary Variance One vs. Rest (EU)
# Random: 0.5000005000000001
# ORC: 0.9305
# Measure: 0.871384892086331
# PRR: 0.8626825166726813
# Metric: ACC, Measure: Binary Variance One vs. Rest (AU)
# Random: 0.5000005000000001
# ORC: 0.9305
# Measure: 0.8767014388489208
# PRR: 0.8750322331359753
# Metric: MAE, Measure: Entropy (TU)
# Random: 0.5000005000000001
# ORC: 0.9395880503144655
# Measure: 0.8801729559748428
# PRR: 0.8648389966978837
# Metric: MAE, Measure: Entropy (EU)
# Random: 0.5000005000000001
# ORC: 0.9395880503144655
# Measure: 0.8711918238993711
# PRR: 0.8444081813368779
# Metric: MAE, Measure: Entropy (AU)
# Random: 0.5000005000000001
# ORC: 0.9395880503144655
# Measure: 0.8803364779874214
# PRR: 0.8652109863333082
# Metric: MAE, Measure: Binary Variance (TU)
# ...
# Random: 0.5000125
# ORC: 0.8120769230769231
# Measure: 0.4638653846153846
# PRR: -0.11583222152723627
# Metric: MSE, Measure: Binary Variance One vs. Rest (AU)
# Random: 0.5000125
# ORC: 0.8120769230769231
# Measure: 0.47013461538461543
# PRR: -0.09574268133737152
# Metric: ACC, Measure: Entropy (TU)
# Random: 0.5000005000000001
# ORC: 0.937
# Measure: 0.8815555555555555
# PRR: 0.8731246959219758
# Metric: ACC, Measure: Entropy (EU)
# Random: 0.5000005000000001
# ORC: 0.937
# Measure: 0.8710238095238095
# PRR: 0.8490245630116499
# Metric: ACC, Measure: Entropy (AU)
# Random: 0.5000005000000001
# ORC: 0.937
# Measure: 0.8821825396825397
# PRR: 0.8745594438495687
# Metric: ACC, Measure: Binary Variance (TU)
# Random: 0.5000005000000001
# ORC: 0.937
# Measure: 0.881515873015873
# PRR: 0.8730338890911155
# Metric: ACC, Measure: Binary Variance (EU)
# Random: 0.5000005000000001
# ORC: 0.937
# Measure: 0.8738571428571429
# PRR: 0.855508170735076
# Metric: ACC, Measure: Binary Variance (AU)
# Random: 0.5000005000000001
# ORC: 0.937
# Measure: 0.881984126984127
# PRR: 0.8741054096952672
# Metric: ACC, Measure: Binary Entropy (TU)
# Random: 0.5000005000000001
# ORC: 0.937
# Measure: 0.8824126984126984
# PRR: 0.8750861234685586
# Metric: ACC, Measure: Binary Entropy (EU)
# Random: 0.5000005000000001
# ORC: 0.937
# Measure: 0.8720793650793651
# PRR: 0.8514400247125341
# Metric: ACC, Measure: Binary Entropy (AU)
# Random: 0.5000005000000001
# ORC: 0.937
# Measure: 0.8828809523809524
# PRR: 0.8761576440727104
# Metric: ACC, Measure: Variance (TU)
# Random: 0.5000005000000001
# ORC: 0.937
# Measure: 0.8829523809523809
# PRR: 0.8763210963682587
# Metric: ACC, Measure: Variance (EU)
# Random: 0.5000005000000001
# ORC: 0.937
# Measure: 0.8756587301587302
# PRR: 0.859630800856134
# Metric: ACC, Measure: Variance (AU)
# Random: 0.5000005000000001
# ORC: 0.937
# Measure: 0.8833968253968254
# PRR: 0.8773381328738943
# Metric: ACC, Measure: Binary Entropy One vs. Rest (TU)
# Random: 0.5000005000000001
# ORC: 0.937
# Measure: 0.8807222222222222
# PRR: 0.8712177524739093
# Metric: ACC, Measure: Binary Entropy One vs. Rest (EU)
# Random: 0.5000005000000001
# ORC: 0.937
# Measure: 0.8693333333333333
# PRR: 0.8451561920170005
# Metric: ACC, Measure: Binary Entropy One vs. Rest (AU)
# Random: 0.5000005000000001
# ORC: 0.937
# Measure: 0.8816984126984126
# PRR: 0.8734516005130729
# Metric: ACC, Measure: Binary Variance One vs. Rest (TU)
# Random: 0.5000005000000001
# ORC: 0.937
# Measure: 0.8794761904761905
# PRR: 0.8683664179848958
# Metric: ACC, Measure: Binary Variance One vs. Rest (EU)
# Random: 0.5000005000000001
# ORC: 0.937
# Measure: 0.8718412698412699
# PRR: 0.8508951837273723
# Metric: ACC, Measure: Binary Variance One vs. Rest (AU)
# Random: 0.5000005000000001
# ORC: 0.937
# Measure: 0.8803809523809524
# PRR: 0.8704368137285107
# Metric: MAE, Measure: Entropy (TU)
# Random: 0.5000005000000001
# ORC: 0.9427753623188406
# Measure: 0.8792753623188406
# PRR: 0.8565862577034152
# Metric: MAE, Measure: Entropy (EU)
# Random: 0.5000005000000001
# ORC: 0.9427753623188406
# Measure: 0.8700579710144928
# PRR: 0.8357689257165094
# Metric: MAE, Measure: Entropy (AU)
# Random: 0.5000005000000001
# ORC: 0.9427753623188406
# Measure: 0.8798550724637682
# PRR: 0.8578955238661137
# Metric: MAE, Measure: Binary Variance (TU)
# Random: 0.5000005000000001
# ORC: 0.9427753623188406
# Measure: 0.8795869565217391
# PRR: 0.8572899882658656
# Metric: MAE, Measure: Binary Variance (EU)
# Random: 0.5000005000000001
# ORC: 0.9427753623188406
# Measure: 0.8726884057971015
# PRR: 0.8417097209297537
# Metric: MAE, Measure: Binary Variance (AU)
# Random: 0.5000005000000001
# ORC: 0.9427753623188406
# Measure: 0.8800579710144928
# PRR: 0.8583537670230582
# Metric: MAE, Measure: Binary Entropy (TU)
# Random: 0.5000005000000001
# ORC: 0.9427753623188406
# Measure: 0.8809492753623189
# PRR: 0.8603667637482072
# Metric: MAE, Measure: Binary Entropy (EU)
# Random: 0.5000005000000001
# ORC: 0.9427753623188406
# Measure: 0.8718768115942029
# PRR: 0.8398767483019759
# Metric: MAE, Measure: Binary Entropy (AU)
# Random: 0.5000005000000001
# ORC: 0.9427753623188406
# Measure: 0.8813115942028986
# PRR: 0.8611850550998937
# Metric: MAE, Measure: Variance (TU)
# Random: 0.5000005000000001
# ORC: 0.9427753623188406
# Measure: 0.8821666666666667
# PRR: 0.8631162226898738
# Metric: MAE, Measure: Variance (EU)
# Random: 0.5000005000000001
# ORC: 0.9427753623188406
# Measure: 0.8755434782608695
# PRR: 0.8481578567810436
# Metric: MAE, Measure: Variance (AU)
# Random: 0.5000005000000001
# ORC: 0.9427753623188406
# Measure: 0.8824275362318841
# PRR: 0.8637053924630882
# Metric: MAE, Measure: Binary Entropy One vs. Rest (TU)
# Random: 0.5000005000000001
# ORC: 0.9427753623188406
# Measure: 0.878159420289855
# PRR: 0.8540659203402206
# Metric: MAE, Measure: Binary Entropy One vs. Rest (EU)
# Random: 0.5000005000000001
# ORC: 0.9427753623188406
# Measure: 0.8686884057971015
# PRR: 0.8326757844071342
# Metric: MAE, Measure: Binary Entropy One vs. Rest (AU)
# Random: 0.5000005000000001
# ORC: 0.9427753623188406
# Measure: 0.8790072463768116
# PRR: 0.8559807221031671
# Metric: MAE, Measure: Binary Variance One vs. Rest (TU)
# Random: 0.5000005000000001
# ORC: 0.9427753623188406
# Measure: 0.8763260869565217
# PRR: 0.8499253661006865
# Metric: MAE, Measure: Binary Variance One vs. Rest (EU)
# Random: 0.5000005000000001
# ORC: 0.9427753623188406
# Measure: 0.8703550724637681
# PRR: 0.8364399246248923
# Metric: MAE, Measure: Binary Variance One vs. Rest (AU)
# Random: 0.5000005000000001
# ORC: 0.9427753623188406
# Measure: 0.8770942028985507
# PRR: 0.851660143766262
# Metric: MSE, Measure: Entropy (TU)
# Random: 0.5000005000000001
# ORC: 0.9531226415094339
# Measure: 0.8749779874213837
# PRR: 0.8275417444229586
# Metric: MSE, Measure: Entropy (EU)
# Random: 0.5000005000000001
# ORC: 0.9531226415094339
# Measure: 0.864185534591195
# PRR: 0.8037237672342098
# Metric: MSE, Measure: Entropy (AU)
# Random: 0.5000005000000001
# ORC: 0.9531226415094339
# Measure: 0.876003144654088
# PRR: 0.8298041746570879
# Metric: MSE, Measure: Binary Variance (TU)
# Random: 0.5000005000000001
# ORC: 0.9531226415094339
# Measure: 0.8757893081761007
# PRR: 0.8293322566941408
# Metric: MSE, Measure: Binary Variance (EU)
# Random: 0.5000005000000001
# ORC: 0.9531226415094339
# Measure: 0.8656320754716981
# PRR: 0.8069161534541469
# Metric: MSE, Measure: Binary Variance (AU)
# Random: 0.5000005000000001
# ORC: 0.9531226415094339
# Measure: 0.876808176100629
# PRR: 0.8315808069881836
# Metric: MSE, Measure: Binary Entropy (TU)
# Random: 0.5000005000000001
# ORC: 0.9531226415094339
# Measure: 0.877814465408805
# PRR: 0.8338015974020527
# Metric: MSE, Measure: Binary Entropy (EU)
# Random: 0.5000005000000001
# ORC: 0.9531226415094339
# Measure: 0.865625786163522
# PRR: 0.8069022735140604
# Metric: MSE, Measure: Binary Entropy (AU)
# Random: 0.5000005000000001
# ORC: 0.9531226415094339
# Measure: 0.8785943396226416
# PRR: 0.8355227099728016
# Metric: MSE, Measure: Variance (TU)
# Random: 0.5000005000000001
# ORC: 0.9531226415094339
# Measure: 0.8801792452830188
# PRR: 0.8390204548746457
# Metric: MSE, Measure: Variance (EU)
# Random: 0.5000005000000001
# ORC: 0.9531226415094339
# Measure: 0.8697452830188679
# PRR: 0.8159936342708378
# Metric: MSE, Measure: Variance (AU)
# Random: 0.5000005000000001
# ORC: 0.9531226415094339
# Measure: 0.8806383647798742
# PRR: 0.8400336905009737
# Metric: MSE, Measure: Binary Entropy One vs. Rest (TU)
# Random: 0.5000005000000001
# ORC: 0.9531226415094339
# Measure: 0.8734119496855346
# PRR: 0.8240856393413744
# Metric: MSE, Measure: Binary Entropy One vs. Rest (EU)
# Random: 0.5000005000000001
# ORC: 0.9531226415094339
# Measure: 0.8632987421383649
# PRR: 0.8017666956819877
# Metric: MSE, Measure: Binary Entropy One vs. Rest (AU)
# Random: 0.5000005000000001
# ORC: 0.9531226415094339
# Measure: 0.8747264150943397
# PRR: 0.8269865468194914
# Metric: MSE, Measure: Binary Variance One vs. Rest (TU)
# Random: 0.5000005000000001
# ORC: 0.9531226415094339
# Measure: 0.8705943396226414
# PRR: 0.81786742618254
# Metric: MSE, Measure: Binary Variance One vs. Rest (EU)
# Random: 0.5000005000000001
# ORC: 0.9531226415094339
# Measure: 0.8642421383647798
# PRR: 0.8038486866949898
# Metric: MSE, Measure: Binary Variance One vs. Rest (AU)
# Random: 0.5000005000000001
# ORC: 0.9531226415094339
# Measure: 0.8721415094339623
# PRR: 0.8212818914438644
# Metric: ACC, Measure: Entropy (TU)
# Random: 0.50000078125
# ORC: 0.98875
# Measure: 0.9786111111111111
# PRR: 0.9792554371445961
# Metric: ACC, Measure: Entropy (EU)
# Random: 0.50000078125
# ORC: 0.98875
# Measure: 0.9696527777777777
# PRR: 0.9609263370874241
# Metric: ACC, Measure: Entropy (AU)
# Random: 0.50000078125
# ORC: 0.98875
# Measure: 0.9795833333333333
# PRR: 0.9812446418019635
# Metric: ACC, Measure: Binary Variance (TU)
# Random: 0.50000078125
# ORC: 0.98875
# Measure: 0.9768055555555555
# PRR: 0.9755611999237707
# Metric: ACC, Measure: Binary Variance (EU)
# Random: 0.50000078125
# ORC: 0.98875
# Measure: 0.97125
# PRR: 0.964194316167385
# Metric: ACC, Measure: Binary Variance (AU)
# Random: 0.50000078125
# ORC: 0.98875
# Measure: 0.9773611111111111
# PRR: 0.9766978882994094
# Metric: ACC, Measure: Binary Entropy (TU)
# Random: 0.50000078125
# ORC: 0.98875
# Measure: 0.9779166666666667
# PRR: 0.9778345766750479
# Metric: ACC, Measure: Binary Entropy (EU)
# Random: 0.50000078125
# ORC: 0.98875
# Measure: 0.9694444444444444
# PRR: 0.9605000789465598
# Metric: ACC, Measure: Binary Entropy (AU)
# Random: 0.50000078125
# ORC: 0.98875
# Measure: 0.9786111111111111
# PRR: 0.9792554371445961
# Metric: ACC, Measure: Variance (TU)
# Random: 0.50000078125
# ORC: 0.98875
# Measure: 0.9769444444444444
# PRR: 0.9758453720176803
# Metric: ACC, Measure: Variance (EU)
# Random: 0.50000078125
# ORC: 0.98875
# Measure: 0.9713888888888889
# PRR: 0.9644784882612947
# Metric: ACC, Measure: Variance (AU)
# Random: 0.50000078125
# ORC: 0.98875
# Measure: 0.9773611111111111
# PRR: 0.9766978882994094
# Metric: ACC, Measure: Binary Entropy One vs. Rest (TU)
# Random: 0.50000078125
# ORC: 0.98875
# Measure: 0.9779166666666667
# PRR: 0.9778345766750479
# Metric: ACC, Measure: Binary Entropy One vs. Rest (EU)
# Random: 0.50000078125
# ORC: 0.98875
# Measure: 0.9678472222222222
# PRR: 0.9572320998665989
# Metric: ACC, Measure: Binary Entropy One vs. Rest (AU)
# Random: 0.50000078125
# ORC: 0.98875
# Measure: 0.9785416666666666
# PRR: 0.9791133510976413
# Metric: ACC, Measure: Binary Variance One vs. Rest (TU)
# Random: 0.50000078125
# ORC: 0.98875
# Measure: 0.9770138888888888
# PRR: 0.9759874580646352
# Metric: ACC, Measure: Binary Variance One vs. Rest (EU)
# Random: 0.50000078125
# ORC: 0.98875
# Measure: 0.9705555555555555
# PRR: 0.9627734556978368
# Metric: ACC, Measure: Binary Variance One vs. Rest (AU)
# Random: 0.50000078125
# ORC: 0.98875
# Measure: 0.9778472222222222
# PRR: 0.977692490628093
# Metric: MAE, Measure: Entropy (TU)
# Random: 0.50000078125
# ORC: 0.9885227272727273
# Measure: 0.9807954545454546
# PRR: 0.9841823426968147
# Metric: MAE, Measure: Entropy (EU)
# Random: 0.50000078125
# ORC: 0.9885227272727273
# Measure: 0.9701704545454546
# PRR: 0.9624330639049348
# Metric: MAE, Measure: Entropy (AU)
# Random: 0.50000078125
# ORC: 0.9885227272727273
# Measure: 0.9814204545454546
# PRR: 0.9854617120375134
# Metric: MAE, Measure: Binary Variance (TU)
# Random: 0.50000078125
# ORC: 0.9885227272727273
# Measure: 0.9790340909090909
# PRR: 0.9805768472821179
# Metric: MAE, Measure: Binary Variance (EU)
# Random: 0.50000078125
# ORC: 0.9885227272727273
# Measure: 0.9724431818181818
# PRR: 0.9670853160529304
# Metric: MAE, Measure: Binary Variance (AU)
# Random: 0.50000078125
# ORC: 0.9885227272727273
# Measure: 0.9797159090909091
# PRR: 0.9819725229265167
# Metric: MAE, Measure: Binary Entropy (TU)
# Random: 0.50000078125
# ORC: 0.9885227272727273
# Measure: 0.9802840909090909
# PRR: 0.9831355859635155
# Metric: MAE, Measure: Binary Entropy (EU)
# Random: 0.50000078125
# ORC: 0.9885227272727273
# Measure: 0.9701704545454546
# PRR: 0.9624330639049348
# Metric: MAE, Measure: Binary Entropy (AU)
# Random: 0.50000078125
# ORC: 0.9885227272727273
# Measure: 0.9808522727272727
# PRR: 0.9842986490005144
# Metric: MAE, Measure: Variance (TU)
# Random: 0.50000078125
# ORC: 0.9885227272727273
# Measure: 0.9795454545454545
# PRR: 0.9816236040154169
# Metric: MAE, Measure: Variance (EU)
# Random: 0.50000078125
# ORC: 0.9885227272727273
# Measure: 0.9733522727272728
# PRR: 0.9689462169121288
# Metric: MAE, Measure: Variance (AU)
# Random: 0.50000078125
# ORC: 0.9885227272727273
# Measure: 0.9797727272727272
# PRR: 0.9820888292302165
# Metric: MAE, Measure: Binary Entropy One vs. Rest (TU)
# Random: 0.50000078125
# ORC: 0.9885227272727273
# Measure: 0.98
# PRR: 0.9825540544450161
# Metric: MAE, Measure: Binary Entropy One vs. Rest (EU)
# Random: 0.50000078125
# ORC: 0.9885227272727273
# Measure: 0.9686363636363636
# PRR: 0.9592927937050376
# Metric: MAE, Measure: Binary Entropy One vs. Rest (AU)
# Random: 0.50000078125
# ORC: 0.9885227272727273
# Measure: 0.9804545454545455
# PRR: 0.9834845048746153
# Metric: MAE, Measure: Binary Variance One vs. Rest (TU)
# Random: 0.50000078125
# ORC: 0.9885227272727273
# Measure: 0.9786363636363636
# PRR: 0.9797627031562187
# Metric: MAE, Measure: Binary Variance One vs. Rest (EU)
# Random: 0.50000078125
# ORC: 0.9885227272727273
# Measure: 0.9714204545454546
# PRR: 0.9649918025863323
# Metric: MAE, Measure: Binary Variance One vs. Rest (AU)
# Random: 0.50000078125
# ORC: 0.9885227272727273
# Measure: 0.9795454545454545
# PRR: 0.9816236040154169
# Metric: MSE, Measure: Entropy (TU)
# Random: 0.50000078125
# ORC: 0.9883405172413793
# Measure: 0.9826508620689656
# PRR: 0.9883489817578266
# Metric: MSE, Measure: Entropy (EU)
# Random: 0.50000078125
# ORC: 0.9883405172413793
# Measure: 0.9695905172413793
# PRR: 0.9616045989746553
# Metric: MSE, Measure: Entropy (AU)
# Random: 0.50000078125
# ORC: 0.9883405172413793
# Measure: 0.9832974137931034
# PRR: 0.989672961103528
# Metric: MSE, Measure: Binary Variance (TU)
# Random: 0.50000078125
# ORC: 0.9883405172413793
# Measure: 0.9810129310344827
# PRR: 0.9849949007487159
# Metric: MSE, Measure: Binary Variance (EU)
# Random: 0.50000078125
# ORC: 0.9883405172413793
# Measure: 0.9718318965517241
# PRR: 0.9661943940397538
# Metric: MSE, Measure: Binary Variance (AU)
# Random: 0.50000078125
# ORC: 0.9883405172413793
# Measure: 0.982176724137931
# PRR: 0.9873780635709786
# Metric: MSE, Measure: Binary Entropy (TU)
# Random: 0.50000078125
# ORC: 0.9883405172413793
# Measure: 0.9825646551724138
# PRR: 0.9881724511783996
# Metric: MSE, Measure: Binary Entropy (EU)
# Random: 0.50000078125
# ORC: 0.9883405172413793
# Measure: 0.9694181034482758
# PRR: 0.9612515378158015
# Metric: MSE, Measure: Binary Entropy (AU)
# Random: 0.50000078125
# ORC: 0.9883405172413793
# Measure: 0.9831681034482759
# PRR: 0.9894081652343878
# Metric: MSE, Measure: Variance (TU)
# Random: 0.50000078125
# ORC: 0.9883405172413793
# Measure: 0.9820905172413793
# PRR: 0.9872015329915518
# Metric: MSE, Measure: Variance (EU)
# Random: 0.50000078125
# ORC: 0.9883405172413793
# Measure: 0.9735560344827586
# PRR: 0.9697250056282914
# Metric: MSE, Measure: Variance (AU)
# Random: 0.50000078125
# ORC: 0.9883405172413793
# Measure: 0.9823922413793104
# PRR: 0.9878193900195459
# Metric: MSE, Measure: Binary Entropy One vs. Rest (TU)
# Random: 0.50000078125
# ORC: 0.9883405172413793
# Measure: 0.9817025862068965
# PRR: 0.9864071453841309
# Metric: MSE, Measure: Binary Entropy One vs. Rest (EU)
# Random: 0.50000078125
# ORC: 0.9883405172413793
# Measure: 0.9675215517241379
# PRR: 0.9573678650684103
# Metric: MSE, Measure: Binary Entropy One vs. Rest (AU)
# Random: 0.50000078125
# ORC: 0.9883405172413793
# Measure: 0.9823060344827587
# PRR: 0.9876428594401191
# Metric: MSE, Measure: Binary Variance One vs. Rest (TU)
# Random: 0.50000078125
# ORC: 0.9883405172413793
# Measure: 0.9796336206896552
# PRR: 0.982170411477886
# Metric: MSE, Measure: Binary Variance One vs. Rest (EU)
# Random: 0.50000078125
# ORC: 0.9883405172413793
# Measure: 0.9702370689655172
# PRR: 0.9629285783203567
# Metric: MSE, Measure: Binary Variance One vs. Rest (AU)
# Random: 0.50000078125
# ORC: 0.9883405172413793
# Measure: 0.9810129310344827
# PRR: 0.9849949007487159
# [[7775  194   36    1    0]
#  [ 282  240  135   26    0]
#  [  49  151  236  109    5]
#  [   2   31  116  246   61]
#  [   0    0    5   70  230]]
#
# Balanced Accuracy:
#   Mean: 0.6092
#   Std:  0.0380
#
# Accuracy:
#   Mean: 0.8727
#   Std:  0.0087
#
# MAE:
#   Mean: 0.1431
#   Std:  0.0124
#
# AMAE:
#   Mean: 0.4377
#   Std:  0.0454
#
# MMAE:
#   Mean: 0.7221
#   Std:  0.0632
#
# QWK:
#   Mean: 0.9110
#   Std:  0.0115
#
# RPS:
#   Mean: 0.1000
#   Std:  0.0099
#
# NLL:
#   Mean: 0.3186
#   Std:  0.0326
#
# BS:
#   Mean: 0.1710
#   Std:  0.0128
#
# UMOD:
#   Mean: 0.9510
#   Std:  0.0082
